# %%
import numpy as np
import cv2 as cv
import PIL.Image as Image
import os
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE = (224,224)
classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/imagenet/mobilenet_v3_large_100_224/classification/5", input_shape=IMAGE_SHAPE+(3,))
])

# %%
sheep = Image.open('photo1.jpg').resize(IMAGE_SHAPE)

# %%
sheep
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sheep = np.array(sheep)/255.0
sheep.shape
# Out:
# (224, 224, 3)

# %%
sheep[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
pred = classifier.predict(sheep[np.newaxis,...])
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
np.argmax(pred)
# Out:
# 349

# %%
with open('labels.txt', 'r') as f:
    labels = f.read().splitlines()
labels[349]
# Out:
# 'ram'
